# %%
import pandas as pd

# %%
price=pd.read_csv('../Data/sell_prices.csv')

# %%
price.head()
# Out:
#   store_id      item_id  wm_yr_wk  sell_price
# 0     CA_1  FOODS_1_001     11101         2.0
# 1     CA_1  FOODS_1_001     11102         2.0
# 2     CA_1  FOODS_1_001     11103         2.0
# 3     CA_1  FOODS_1_001     11104         2.0
# 4     CA_1  FOODS_1_001     11105         2.0

# %%
price.store_id.unique()
# Out:
# array(['CA_1', 'CA_2', 'CA_3', 'CA_4', 'TX_1', 'TX_2', 'TX_3', 'WI_1',
#        'WI_2', 'WI_3'], dtype=object)

# %%
price.item_id.unique().sum()
# Out:
# 'FOODS_1_001FOODS_1_002FOODS_1_003FOODS_1_004FOODS_1_005FOODS_1_006FOODS_1_008FOODS_1_009FOODS_1_010'

# %%
price[price['item_id']=='FOODS_1_001']
# Out:
#         store_id      item_id  wm_yr_wk  sell_price
# 368746      CA_1  FOODS_1_001     11101        2.00
# 368747      CA_1  FOODS_1_001     11102        2.00
# 368748      CA_1  FOODS_1_001     11103        2.00
# 368749      CA_1  FOODS_1_001     11104        2.00
# 368750      CA_1  FOODS_1_001     11105        2.00
# ...          ...          ...       ...         ...
# 6512832     WI_3  FOODS_1_001     11617        2.24
# 6512833     WI_3  FOODS_1_001     11618        2.24
# 6512834     WI_3  FOODS_1_001     11619        2.24
# 6512835     WI_3  FOODS_1_001     11620        2.24
# 6512836     WI_3  FOODS_1_001     11621        2.24
#
# [2819 rows x 4 columns]

# %%
selected_food_items=['FOODS_1_001','FOODS_1_002','FOODS_1_003','FOODS_1_004','FOODS_1_005','FOODS_1_006','FOODS_1_007','FOODS_1_008','FOODS_1_009','FOODS_1_010']

# %%
Data_price=price[price['item_id'].isin(selected_food_items)]
Data_price.head()
# Out:
#        store_id      item_id  wm_yr_wk  sell_price
# 368746     CA_1  FOODS_1_001     11101         2.0
# 368747     CA_1  FOODS_1_001     11102         2.0
# 368748     CA_1  FOODS_1_001     11103         2.0
# 368749     CA_1  FOODS_1_001     11104         2.0
# 368750     CA_1  FOODS_1_001     11105         2.0

# %%
Data_price.wm_yr_wk.nunique()
# Out:
# 282

# %%
Data_price.shape
# Out:
# (23283, 4)

# %%
orders_eval=pd.read_csv('sales_train_evaluation.csv')

# %%
orders_eval
# Out:
#                                   id        item_id    dept_id   cat_id  \
# 0      HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 1      HOBBIES_1_002_CA_1_evaluation  HOBBIES_1_002  HOBBIES_1  HOBBIES
# 2      HOBBIES_1_003_CA_1_evaluation  HOBBIES_1_003  HOBBIES_1  HOBBIES
# 3      HOBBIES_1_004_CA_1_evaluation  HOBBIES_1_004  HOBBIES_1  HOBBIES
# 4      HOBBIES_1_005_CA_1_evaluation  HOBBIES_1_005  HOBBIES_1  HOBBIES
# ...                              ...            ...        ...      ...
# 30485    FOODS_3_823_WI_3_evaluation    FOODS_3_823    FOODS_3    FOODS
# 30486    FOODS_3_824_WI_3_evaluation    FOODS_3_824    FOODS_3    FOODS
# 30487    FOODS_3_825_WI_3_evaluation    FOODS_3_825    FOODS_3    FOODS
# 30488    FOODS_3_826_WI_3_evaluation    FOODS_3_826    FOODS_3    FOODS
# 30489    FOODS_3_827_WI_3_evaluation    FOODS_3_827    FOODS_3    FOODS
#
#       store_id state_id  d_1  d_2  d_3  d_4  ...  d_1932  d_1933  d_1934  \
# ...

# %%
orders.shape
# Out:
# (30490, 1947)

# %%
orders_val=pd.read_csv('sales_train_validation.csv')

# %%
orders_val.shape
# Out:
# (30490, 1919)

# %%
Data_orders_eval=orders_eval[orders_eval['item_id'].isin(selected_food_items)]

# %%
Data_orders_eval
# Out:
#                                 id      item_id  dept_id cat_id store_id  \
# 1612   FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 1613   FOODS_1_002_CA_1_evaluation  FOODS_1_002  FOODS_1  FOODS     CA_1
# 1614   FOODS_1_003_CA_1_evaluation  FOODS_1_003  FOODS_1  FOODS     CA_1
# 1615   FOODS_1_004_CA_1_evaluation  FOODS_1_004  FOODS_1  FOODS     CA_1
# 1616   FOODS_1_005_CA_1_evaluation  FOODS_1_005  FOODS_1  FOODS     CA_1
# ...                            ...          ...      ...    ...      ...
# 29057  FOODS_1_005_WI_3_evaluation  FOODS_1_005  FOODS_1  FOODS     WI_3
# 29058  FOODS_1_006_WI_3_evaluation  FOODS_1_006  FOODS_1  FOODS     WI_3
# 29059  FOODS_1_008_WI_3_evaluation  FOODS_1_008  FOODS_1  FOODS     WI_3
# 29060  FOODS_1_009_WI_3_evaluation  FOODS_1_009  FOODS_1  FOODS     WI_3
# 29061  FOODS_1_010_WI_3_evaluation  FOODS_1_010  FOODS_1  FOODS     WI_3
#
#       state_id  d_1  d_2  d_3  d_4  ...  d_1932  d_1933  d_1934  d_1935  \
# ...

# %%
calendar=pd.read_csv('calendar.csv')
calendar.head()
# Out:
#       date  wm_yr_wk    weekday  wday  month  year  day event_name_1  \
# 0  1/29/11     11101   Saturday     1      1  2011  d_1          NaN
# 1  1/30/11     11101     Sunday     2      1  2011  d_2          NaN
# 2  1/31/11     11101     Monday     3      1  2011  d_3          NaN
# 3   2/1/11     11101    Tuesday     4      2  2011  d_4          NaN
# 4   2/2/11     11101  Wednesday     5      2  2011  d_5          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
# 2          NaN          NaN          NaN        0        0        0
# 3          NaN          NaN          NaN        1        1        0
# 4          NaN          NaN          NaN        1        0        1

# %%
Data_price.to_csv('price.csv')
Data_orders_eval.to_csv('orders.csv')

# %%
melted_order_eval=pd.melt(Data_orders_eval,id_vars=['id','item_id',	'dept_id','cat_id','store_id','state_id'], var_name='day',value_name='order')

# %%
melted_order_eval
# Out:
#                                  id      item_id  dept_id cat_id store_id  \
# 0       FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 1       FOODS_1_002_CA_1_evaluation  FOODS_1_002  FOODS_1  FOODS     CA_1
# 2       FOODS_1_003_CA_1_evaluation  FOODS_1_003  FOODS_1  FOODS     CA_1
# 3       FOODS_1_004_CA_1_evaluation  FOODS_1_004  FOODS_1  FOODS     CA_1
# 4       FOODS_1_005_CA_1_evaluation  FOODS_1_005  FOODS_1  FOODS     CA_1
# ...                             ...          ...      ...    ...      ...
# 174685  FOODS_1_005_WI_3_evaluation  FOODS_1_005  FOODS_1  FOODS     WI_3
# 174686  FOODS_1_006_WI_3_evaluation  FOODS_1_006  FOODS_1  FOODS     WI_3
# 174687  FOODS_1_008_WI_3_evaluation  FOODS_1_008  FOODS_1  FOODS     WI_3
# 174688  FOODS_1_009_WI_3_evaluation  FOODS_1_009  FOODS_1  FOODS     WI_3
# 174689  FOODS_1_010_WI_3_evaluation  FOODS_1_010  FOODS_1  FOODS     WI_3
#
#        state_id     day  order
# 0            CA     d_1      3
# ...

# %%
merge1=pd.merge(melted_order_eval,calendar,on='day')

# %%
merge1.shape
# Out:
# (174690, 21)

# %%
merge1
# Out:
#                                  id      item_id  dept_id cat_id store_id  \
# 0       FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 1       FOODS_1_002_CA_1_evaluation  FOODS_1_002  FOODS_1  FOODS     CA_1
# 2       FOODS_1_003_CA_1_evaluation  FOODS_1_003  FOODS_1  FOODS     CA_1
# 3       FOODS_1_004_CA_1_evaluation  FOODS_1_004  FOODS_1  FOODS     CA_1
# 4       FOODS_1_005_CA_1_evaluation  FOODS_1_005  FOODS_1  FOODS     CA_1
# ...                             ...          ...      ...    ...      ...
# 174685  FOODS_1_005_WI_3_evaluation  FOODS_1_005  FOODS_1  FOODS     WI_3
# 174686  FOODS_1_006_WI_3_evaluation  FOODS_1_006  FOODS_1  FOODS     WI_3
# 174687  FOODS_1_008_WI_3_evaluation  FOODS_1_008  FOODS_1  FOODS     WI_3
# 174688  FOODS_1_009_WI_3_evaluation  FOODS_1_009  FOODS_1  FOODS     WI_3
# 174689  FOODS_1_010_WI_3_evaluation  FOODS_1_010  FOODS_1  FOODS     WI_3
#
#        state_id     day  order     date  wm_yr_wk  ... wday  month  year  \
# ...

# %%
joint_1=melted_order.join(calendar.set_index('day'), on='day')

# %%
joint_1
# Out:
#                                  id      item_id  dept_id cat_id store_id  \
# 0       FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 1       FOODS_1_002_CA_1_evaluation  FOODS_1_002  FOODS_1  FOODS     CA_1
# 2       FOODS_1_003_CA_1_evaluation  FOODS_1_003  FOODS_1  FOODS     CA_1
# 3       FOODS_1_004_CA_1_evaluation  FOODS_1_004  FOODS_1  FOODS     CA_1
# 4       FOODS_1_005_CA_1_evaluation  FOODS_1_005  FOODS_1  FOODS     CA_1
# ...                             ...          ...      ...    ...      ...
# 174685  FOODS_1_005_WI_3_evaluation  FOODS_1_005  FOODS_1  FOODS     WI_3
# 174686  FOODS_1_006_WI_3_evaluation  FOODS_1_006  FOODS_1  FOODS     WI_3
# 174687  FOODS_1_008_WI_3_evaluation  FOODS_1_008  FOODS_1  FOODS     WI_3
# 174688  FOODS_1_009_WI_3_evaluation  FOODS_1_009  FOODS_1  FOODS     WI_3
# 174689  FOODS_1_010_WI_3_evaluation  FOODS_1_010  FOODS_1  FOODS     WI_3
#
#        state_id     day  order     date  wm_yr_wk  ... wday  month  year  \
# ...

# %%
joint_1.to_csv('joint1.csv')

# %%
joint_1.wm_yr_wk.nunique()
# Out:
# 278

# %%
merge=pd.merge(joint_1,Data_price, on=['wm_yr_wk','store_id','item_id'],how='left')

# %%
merge.shape
# Out:
# (174690, 22)

# %%
merge.head()
# Out:
#                             id      item_id  dept_id cat_id store_id state_id  \
# 0  FOODS_1_001_CA_1_evaluation  FOODS_1_001  FOODS_1  FOODS     CA_1       CA
# 1  FOODS_1_002_CA_1_evaluation  FOODS_1_002  FOODS_1  FOODS     CA_1       CA
# 2  FOODS_1_003_CA_1_evaluation  FOODS_1_003  FOODS_1  FOODS     CA_1       CA
# 3  FOODS_1_004_CA_1_evaluation  FOODS_1_004  FOODS_1  FOODS     CA_1       CA
# 4  FOODS_1_005_CA_1_evaluation  FOODS_1_005  FOODS_1  FOODS     CA_1       CA
#
#    day  order     date  wm_yr_wk  ... month  year  event_name_1  event_type_1  \
# 0  d_1      3  1/29/11     11101  ...     1  2011           NaN           NaN
# 1  d_1      0  1/29/11     11101  ...     1  2011           NaN           NaN
# 2  d_1      0  1/29/11     11101  ...     1  2011           NaN           NaN
# 3  d_1      0  1/29/11     11101  ...     1  2011           NaN           NaN
# 4  d_1      3  1/29/11     11101  ...     1  2011           NaN           NaN
#
# ...

# %%
merge.to_csv('walmart_food_orders.csv')

# %%
orders_val=pd.read_csv('sales_train_validation.csv')

# %%
data_order_val=orders_val[orders_val['item_id'].isin(selected_food_items)]

# %%
data_order_val
# Out:
#                                 id      item_id  dept_id cat_id store_id  \
# 1612   FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 1613   FOODS_1_002_CA_1_validation  FOODS_1_002  FOODS_1  FOODS     CA_1
# 1614   FOODS_1_003_CA_1_validation  FOODS_1_003  FOODS_1  FOODS     CA_1
# 1615   FOODS_1_004_CA_1_validation  FOODS_1_004  FOODS_1  FOODS     CA_1
# 1616   FOODS_1_005_CA_1_validation  FOODS_1_005  FOODS_1  FOODS     CA_1
# ...                            ...          ...      ...    ...      ...
# 29057  FOODS_1_005_WI_3_validation  FOODS_1_005  FOODS_1  FOODS     WI_3
# 29058  FOODS_1_006_WI_3_validation  FOODS_1_006  FOODS_1  FOODS     WI_3
# 29059  FOODS_1_008_WI_3_validation  FOODS_1_008  FOODS_1  FOODS     WI_3
# 29060  FOODS_1_009_WI_3_validation  FOODS_1_009  FOODS_1  FOODS     WI_3
# 29061  FOODS_1_010_WI_3_validation  FOODS_1_010  FOODS_1  FOODS     WI_3
#
#       state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  d_1907  \
# ...

# %%
data

# %%
melt_val=pd.melt(data_order_val,id_vars=['id','item_id','dept_id','cat_id','store_id','state_id'], var_name='day',value_name='order')

# %%
melt_val
# Out:
#                                  id      item_id  dept_id cat_id store_id  \
# 0       FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 1       FOODS_1_002_CA_1_validation  FOODS_1_002  FOODS_1  FOODS     CA_1
# 2       FOODS_1_003_CA_1_validation  FOODS_1_003  FOODS_1  FOODS     CA_1
# 3       FOODS_1_004_CA_1_validation  FOODS_1_004  FOODS_1  FOODS     CA_1
# 4       FOODS_1_005_CA_1_validation  FOODS_1_005  FOODS_1  FOODS     CA_1
# ...                             ...          ...      ...    ...      ...
# 172165  FOODS_1_005_WI_3_validation  FOODS_1_005  FOODS_1  FOODS     WI_3
# 172166  FOODS_1_006_WI_3_validation  FOODS_1_006  FOODS_1  FOODS     WI_3
# 172167  FOODS_1_008_WI_3_validation  FOODS_1_008  FOODS_1  FOODS     WI_3
# 172168  FOODS_1_009_WI_3_validation  FOODS_1_009  FOODS_1  FOODS     WI_3
# 172169  FOODS_1_010_WI_3_validation  FOODS_1_010  FOODS_1  FOODS     WI_3
#
#        state_id     day  order
# 0            CA     d_1      3
# ...

# %%
join_val=pd.merge(melt_val,calendar,on='day')

# %%
join_val
# Out:
#                                  id      item_id  dept_id cat_id store_id  \
# 0       FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 1       FOODS_1_002_CA_1_validation  FOODS_1_002  FOODS_1  FOODS     CA_1
# 2       FOODS_1_003_CA_1_validation  FOODS_1_003  FOODS_1  FOODS     CA_1
# 3       FOODS_1_004_CA_1_validation  FOODS_1_004  FOODS_1  FOODS     CA_1
# 4       FOODS_1_005_CA_1_validation  FOODS_1_005  FOODS_1  FOODS     CA_1
# ...                             ...          ...      ...    ...      ...
# 172165  FOODS_1_005_WI_3_validation  FOODS_1_005  FOODS_1  FOODS     WI_3
# 172166  FOODS_1_006_WI_3_validation  FOODS_1_006  FOODS_1  FOODS     WI_3
# 172167  FOODS_1_008_WI_3_validation  FOODS_1_008  FOODS_1  FOODS     WI_3
# 172168  FOODS_1_009_WI_3_validation  FOODS_1_009  FOODS_1  FOODS     WI_3
# 172169  FOODS_1_010_WI_3_validation  FOODS_1_010  FOODS_1  FOODS     WI_3
#
#        state_id     day  order     date  wm_yr_wk  ... wday  month  year  \
# ...

# %%
data_wal_val=pd.merge(join_val,Data_price,on=['wm_yr_wk','store_id','item_id'],how='left')

# %%
data_wal_val
# Out:
#                                  id      item_id  dept_id cat_id store_id  \
# 0       FOODS_1_001_CA_1_validation  FOODS_1_001  FOODS_1  FOODS     CA_1
# 1       FOODS_1_002_CA_1_validation  FOODS_1_002  FOODS_1  FOODS     CA_1
# 2       FOODS_1_003_CA_1_validation  FOODS_1_003  FOODS_1  FOODS     CA_1
# 3       FOODS_1_004_CA_1_validation  FOODS_1_004  FOODS_1  FOODS     CA_1
# 4       FOODS_1_005_CA_1_validation  FOODS_1_005  FOODS_1  FOODS     CA_1
# ...                             ...          ...      ...    ...      ...
# 172165  FOODS_1_005_WI_3_validation  FOODS_1_005  FOODS_1  FOODS     WI_3
# 172166  FOODS_1_006_WI_3_validation  FOODS_1_006  FOODS_1  FOODS     WI_3
# 172167  FOODS_1_008_WI_3_validation  FOODS_1_008  FOODS_1  FOODS     WI_3
# 172168  FOODS_1_009_WI_3_validation  FOODS_1_009  FOODS_1  FOODS     WI_3
# 172169  FOODS_1_010_WI_3_validation  FOODS_1_010  FOODS_1  FOODS     WI_3
#
#        state_id     day  order     date  wm_yr_wk  ... month  year  \
# ...

# %%
data_wal_val.to_csv('walmart_food_orders_train.csv')
